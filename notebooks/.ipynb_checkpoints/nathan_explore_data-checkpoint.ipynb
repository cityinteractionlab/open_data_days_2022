# %% [markdown]
# # Explore datasets
#
# This is a playground notebook : the goal is to explore all datasets (quickly)

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import display, Markdown

# %% [markdown]
# ## Velib data

# %%
velib_depart = pd.read_excel("../data_velib/2021_S1_Stations_departs_Paris.xlsx")
velib_arrival = pd.read_excel("../data_velib/2021_S1_Stations_arrivees_Paris.xlsx")
velib_info = pd.read_csv("../data_velib/velib-emplacement-des-stations.csv", sep=";")

# %%
def preprocess_velib_data(df, type="departure"):
    df.columns = ["ID_station", "station_name"] + list(velib_depart.columns)[2:]
    df = df.iloc[1:-2]
    df_processed = df.melt(["ID_station", "station_name"], value_vars=df.columns[2:])
    df_processed.columns = ['ID_station', 'station_name', 'month', 'value']
    df_processed["type"] = type
    
    return df_processed

# %%
depart_df = preprocess_velib_data(velib_depart, type="departure")
arrival_df = preprocess_velib_data(velib_arrival, type="arrival")

# %%
velib_df = pd.concat([depart_df, arrival_df]).reset_index(drop=True)

# %%
velib_df.to_csv("../data_velib/arrivals_departure_velib_2021.csv", sep=";", index=False)

# %% [markdown]
# ## Comptage vélo

# %%
data = pd.read_csv("../external_data/comptage-velo-compteurs.csv", sep=";")

# %%
data
# Out:
#    Identifiant du compteur                     Nom du compteur  \
# 0      100003096-353242251   97 avenue Denfert Rochereau SO-NE
# 1             100003097-SC              105 rue La Fayette E-O
# 2             100003098-SC  106 avenue Denfert Rochereau NE-SO
# 3      100003099-353242239              100 rue La Fayette O-E
# 4             100006300-SC          135 avenue Daumesnil SE-NO
# ..                     ...                                 ...
# 94     100065336-104065336  35 boulevard de Ménilmontant NO-SE
# 95     300014702-353245971          254 rue de Vaugirard SO-NE
# 96     300014702-353245972          254 rue de Vaugirard NE-SO
# 97            300021312-SC            30 rue Saint Jacques N-S
# 98            300021320-SC             69 Boulevard Ornano N-S
#
#     Identifiant du site de comptage             Nom du site de comptage  \
# 0                         100003096         97 avenue Denfert Rochereau
# 1                         100003097              105 rue La Fayette E-O
# 2                         100003098  106 avenue Denfert Rochereau NE-SO
# 3                         100003099                  100 rue La Fayette
# 4                         100006300          135 avenue Daumesnil SE-NO
# ..                              ...                                 ...
# 94                        100065336        35 boulevard de Ménilmontant
# 95                        300014702                254 rue de Vaugirard
# 96                        300014702                254 rue de Vaugirard
# 97                        300021312            30 rue Saint Jacques N-S
# 98                        300021320             69 Boulevard Ornano N-S
#
#    Identifiant du channel Nom du channel  \
# 0               353242251          SO-NE
# 1                      SC            NaN
# 2                      SC            NaN
# 3               353242239            O-E
# 4                      SC            NaN
# ..                    ...            ...
# 94              104065336          NO-SE
# 95              353245971          SO-NE
# 96              353245972          NE-SO
# 97                     SC            NaN
# 98                     SC            NaN
#
#    Date d'installation du site de comptage  \
# 0                               2012-02-22
# 1                               2012-02-13
# 2                               2012-02-22
# 3                               2012-02-22
# 4                               2013-01-19
# ..                                     ...
# 94                              2020-11-18
# 95                              2020-11-29
# 96                              2020-11-29
# 97                              2021-11-30
# 98                              2021-11-30
#
#                   Lien vers photo du site de comptage  \
# 0   https://filer.eco-counter-tools.com/file/10/6d...
# 1   https://filer.eco-counter-tools.com/file/fb/bd...
# 2   https://filer.eco-counter-tools.com/file/ad/53...
# 3   https://filer.eco-counter-tools.com/file/4e/6c...
# 4   https://filer.eco-counter-tools.com/file/97/3f...
# ..                                                ...
# 94                                                NaN
# 95  https://filer.eco-counter-tools.com/file/ea/42...
# 96  https://filer.eco-counter-tools.com/file/ea/42...
# 97  https://filer.eco-counter-tools.com/file/20/c9...
# 98  https://filer.eco-counter-tools.com/file/e1/da...
#
#    Identifiant technique compteur Coordonnées géographiques  \
# 0                     X2H20012081          48.83511,2.33338
# 1                     Y2H21100756           48.87773,2.3506
# 2                     Y2H16029278          48.83521,2.33307
# 3                     Y2H21100755           48.87813,2.3497
# 4                     X2H18086316        48.843435,2.383378
# ..                            ...                       ...
# 94                            NaN        48.860528,2.388364
# 95                    Y2H20114504          48.83977,2.30198
# 96                    Y2H20114504          48.83977,2.30198
# 97                    Y2H21110998        48.851131,2.345678
# 98                    Y2H21110997          48.89683,2.34521
#
#                                             ID Photos  \
# 0   https://filer.eco-counter-tools.com/file/10/6d...
# 1   https://filer.eco-counter-tools.com/file/fb/bd...
# 2   https://filer.eco-counter-tools.com/file/ad/53...
# 3   https://filer.eco-counter-tools.com/file/4e/6c...
# 4   https://filer.eco-counter-tools.com/file/97/3f...
# ..                                                ...
# 94                                                NaN
# 95  https://filer.eco-counter-tools.com/file/ea/42...
# 96  https://filer.eco-counter-tools.com/file/ea/42...
# 97  https://filer.eco-counter-tools.com/file/20/c9...
# 98  https://filer.eco-counter-tools.com/file/e1/da...
#
#            test_lien_vers_photos_du_site_de_comptage_ id_photo_1  \
# 0   https://filer.eco-counter-tools.com/file/10/6d...     https:
# 1   https://filer.eco-counter-tools.com/file/fb/bd...     https:
# 2   https://filer.eco-counter-tools.com/file/ad/53...     https:
# 3   https://filer.eco-counter-tools.com/file/4e/6c...     https:
# 4   https://filer.eco-counter-tools.com/file/97/3f...     https:
# ..                                                ...        ...
# 94                                                NaN        NaN
# 95  https://filer.eco-counter-tools.com/file/ea/42...     https:
# 96  https://filer.eco-counter-tools.com/file/ea/42...     https:
# 97  https://filer.eco-counter-tools.com/file/20/c9...     https:
# 98  https://filer.eco-counter-tools.com/file/e1/da...     https:
#
#                                      url_sites type_dimage
# 0   https://www.eco-visio.net/Photos/100003096         jpg
# 1   https://www.eco-visio.net/Photos/100003097         jpg
# 2   https://www.eco-visio.net/Photos/100003098         jpg
# 3   https://www.eco-visio.net/Photos/100003099         jpg
# 4   https://www.eco-visio.net/Photos/100006300         jpg
# ..                                         ...         ...
# 94  https://www.eco-visio.net/Photos/100065336         NaN
# 95  https://www.eco-visio.net/Photos/300014702         jpg
# 96  https://www.eco-visio.net/Photos/300014702         jpg
# 97  https://www.eco-visio.net/Photos/300021312         jpg
# 98  https://www.eco-visio.net/Photos/300021320         jpg
#
# [99 rows x 15 columns]
